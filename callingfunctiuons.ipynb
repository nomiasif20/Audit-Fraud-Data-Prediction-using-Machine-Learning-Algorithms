# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/PythonProject/makingfunctions.py /content

# %%
import makingfunctions
# Out:
# Mounted at /PythonProject
#     Sector_score LOCATION_ID PARA_A Score_A Risk_A PARA_B Score_B Risk_B  \
# 0           3.89          23   4.18     0.6  2.508    2.5     0.2    0.5
# 1           3.89           6    0.0     0.2    0.0   4.83     0.2  0.966
# 2           3.89           6   0.51     0.2  0.102   0.23     0.2  0.046
# 3           3.89           6    0.0     0.2    0.0   10.8     0.6   6.48
# 4           3.89           6    0.0     0.2    0.0   0.08     0.2  0.016
# ..           ...         ...    ...     ...    ...    ...     ...    ...
# 771        55.57           9   0.49     0.2  0.098    0.4     0.2   0.08
# 772        55.57          16   0.47     0.2  0.094   0.37     0.2  0.074
# 773        55.57          14   0.24     0.2  0.048   0.04     0.2  0.008
# 774        55.57          18    0.2     0.2   0.04    0.0     0.2    0.0
# 775        55.57          15    0.0     0.2    0.0    0.0     0.2    0.0
#
# ...

# %%
#makingfunctions.Dataset()
makingfunctions.c.read_file()
makingfunctions.c.data_preprocessing()
makingfunctions.c.plot_variables()
# Out:
#     Sector_score LOCATION_ID PARA_A Score_A Risk_A PARA_B Score_B Risk_B  \
# 0           3.89          23   4.18     0.6  2.508    2.5     0.2    0.5
# 1           3.89           6    0.0     0.2    0.0   4.83     0.2  0.966
# 2           3.89           6   0.51     0.2  0.102   0.23     0.2  0.046
# 3           3.89           6    0.0     0.2    0.0   10.8     0.6   6.48
# 4           3.89           6    0.0     0.2    0.0   0.08     0.2  0.016
# ..           ...         ...    ...     ...    ...    ...     ...    ...
# 771        55.57           9   0.49     0.2  0.098    0.4     0.2   0.08
# 772        55.57          16   0.47     0.2  0.094   0.37     0.2  0.074
# 773        55.57          14   0.24     0.2  0.048   0.04     0.2  0.008
# 774        55.57          18    0.2     0.2   0.04    0.0     0.2    0.0
# 775        55.57          15    0.0     0.2    0.0    0.0     0.2    0.0
#
#     TOTAL numbers  ... RiSk_E History Prob Risk_F Score Inherent_Risk  \
# ...
